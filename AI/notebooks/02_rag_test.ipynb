# %%
# ===== 셀 1: 환경 로딩 =====
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# ===== 셀 2: 샘플 문서 준비 =====
# 실제로는 PDF 로딩하지만, 테스트용 샘플 텍스트
sample_docs = [
    """
    [NH투자증권 리포트 - 2025.10.15]
    삼성전자 목표주가: 90,000원
    투자의견: 매수
    AI 반도체 시장에서 삼성전자는 NVIDIA 대비 경쟁력을 확보하고 있습니다.
    HBM3E 양산이 시작되면서 수익성 개선이 예상됩니다.
    """,
    """
    [한국투자증권 리포트 - 2025.10.10]
    네이버 목표주가: 250,000원
    투자의견: 매수
    AI 검색 서비스 확대로 광고 매출 증가가 기대됩니다.
    """,
    """
    [미래에셋증권 리포트 - 2025.10.12]
    현대차 목표주가: 280,000원
    투자의견: 중립
    전기차 시장 경쟁 심화로 단기 실적 압박이 예상됩니다.
    """
]

# ===== 셀 3: 텍스트 청킹 =====
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

# Document 객체로 변환
documents = [Document(page_content=text) for text in sample_docs]

# 청킹 (실제로는 큰 PDF라서 필요, 여기선 작아서 의미 없음)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)
chunks = text_splitter.split_documents(documents)
print(f"총 {len(chunks)}개 청크 생성")

# ===== 셀 4: 임베딩 및 ChromaDB 저장 =====
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# 임베딩 생성
embeddings = OpenAIEmbeddings(openai_api_key=api_key)

# ChromaDB 생성 (테스트용 별도 디렉토리)
db = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="./embeddings/test_db",
    collection_name="test_reports"
)
print("ChromaDB 생성 완료!")

# ===== 셀 5: 유사도 검색 테스트 =====
query = "삼성전자 AI 반도체 전망은?"
results = db.similarity_search(query, k=2)

print(f"질문: {query}\n")
for i, doc in enumerate(results, 1):
    print(f"[검색 결과 {i}]")
    print(doc.page_content)
    print()

# ===== 셀 6: RAG 체인 구축 =====
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

# LLM
llm = ChatOpenAI(
    model="gpt-4-turbo-preview",
    temperature=0.3,
    openai_api_key=api_key
)

# Retriever
retriever = db.as_retriever(search_kwargs={"k": 2})

# 프롬프트
prompt_template = """
당신은 전문 투자 상담가입니다.
아래 증권사 리포트를 참고하여 질문에 답변하세요.

참고 문서:
{context}

질문: {question}

답변 지침:
1. 참고 문서의 내용을 기반으로 정확히 답변하세요
2. 출처를 명확히 밝히세요 (예: "NH투자증권 리포트에 따르면...")
3. 초보 투자자도 이해할 수 있도록 쉽게 설명하세요

답변:
"""

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template
)

# RAG Chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)

# ===== 셀 7: RAG 질의 테스트 =====
test_questions = [
    "삼성전자의 AI 반도체 전망은?",
    "네이버 주가 목표가는?",
    "현대차 투자의견은?"
]

for q in test_questions:
    print(f"\n{'='*60}")
    print(f"질문: {q}")
    print('='*60)
    
    result = qa_chain({"query": q})
    answer = result["result"]
    sources = result["source_documents"]
    
    print(f"\n답변:\n{answer}\n")
    
    print("출처:")
    for i, doc in enumerate(sources, 1):
        print(f"  [{i}] {doc.page_content[:100]}...")
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import sys
#       3 print(sys.version)  # 3.10.x 또는 3.11.x 추천. 3.12 이상이면 3.10/3.11로 새 가상환경 생성이 가장 확실!
# ----> 6 from langchain.chains import RetrievalQA
#       7 from langchain_openai import ChatOpenAI
#       8 from langchain_community.vectorstores import Chroma
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\invest_project\AI\venv\Lib\site-packages\langchain\chains\__init__.py:92, in __getattr__(name)
#      91 def __getattr__(name: str) -> Any:
# ---> 92     return importer(name)
#
# File c:\invest_project\AI\venv\Lib\site-packages\langchain\_api\module_import.py:96, in create_importer.<locals>.import_by_name(name)
#      90     raise AssertionError(
#      91         f"Importing from {new_module} is not allowed. "
#      92         f"Allowed top-level packages are: {ALLOWED_TOP_LEVEL_PKGS}"
#      93     )
#      95 try:
# ---> 96     module = importlib.import_module(new_module)
#      97 except ModuleNotFoundError as e:
#      98     if new_module.startswith("langchain_community"):
#
# File ~\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\invest_project\AI\venv\Lib\site-packages\langchain\chains\retrieval_qa\base.py:10
#       7 from typing import Any, Dict, List, Optional
#       9 from langchain_core._api import deprecated
# ---> 10 from langchain_core.callbacks import (
#      11     AsyncCallbackManagerForChainRun,
#      12     CallbackManagerForChainRun,
#      13     Callbacks,
#      14 )
#      15 from langchain_core.documents import Document
#      16 from langchain_core.language_models import BaseLanguageModel
#
# File c:\invest_project\AI\venv\Lib\site-packages\langchain_core\callbacks\__init__.py:22
#       9 from langchain_core.callbacks.base import (
#      10     AsyncCallbackHandler,
#      11     BaseCallbackHandler,
#    (...)     19     ToolManagerMixin,
#      20 )
#      21 from langchain_core.callbacks.file import FileCallbackHandler
# ---> 22 from langchain_core.callbacks.manager import (
#      23     AsyncCallbackManager,
#      24     AsyncCallbackManagerForChainGroup,
#      25     AsyncCallbackManagerForChainRun,
#      26     AsyncCallbackManagerForLLMRun,
#      27     AsyncCallbackManagerForRetrieverRun,
#      28     AsyncCallbackManagerForToolRun,
#      29     AsyncParentRunManager,
#      30     AsyncRunManager,
#      31     BaseRunManager,
#      32     CallbackManager,
#      33     CallbackManagerForChainGroup,
#      34     CallbackManagerForChainRun,
#      35     CallbackManagerForLLMRun,
#      36     CallbackManagerForRetrieverRun,
#      37     CallbackManagerForToolRun,
#      38     ParentRunManager,
#      39     RunManager,
#      40 )
#      41 from langchain_core.callbacks.stdout import StdOutCallbackHandler
#      42 from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#
# File c:\invest_project\AI\venv\Lib\site-packages\langchain_core\callbacks\manager.py:29
#      11 from typing import (
#      12     TYPE_CHECKING,
#      13     Any,
#    (...)     25     cast,
#      26 )
#      27 from uuid import UUID
# ---> 29 from langsmith.run_helpers import get_run_tree_context
#      30 from tenacity import RetryCallState
#      32 from langchain_core.callbacks.base import (
#      33     BaseCallbackHandler,
#      34     BaseCallbackManager,
#    (...)     40     ToolManagerMixin,
#      41 )
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\run_helpers.py:40
#      15 from typing import (
#      16     TYPE_CHECKING,
#      17     Any,
#    (...)     35     runtime_checkable,
#      36 )
#      38 from typing_extensions import ParamSpec, TypeGuard
# ---> 40 from langsmith import client as ls_client
#      41 from langsmith import run_trees, utils
#      42 from langsmith._internal import _aiter as aitertools
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\client.py:52
#      49 from urllib3.util import Retry
#      51 import langsmith
# ---> 52 from langsmith import env as ls_env
#      53 from langsmith import schemas as ls_schemas
#      54 from langsmith import utils as ls_utils
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\env\__init__.py:3
#       1 """Utilities to get information about the runtime environment."""
#       2 from langsmith.env._git import get_git_info
# ----> 3 from langsmith.env._runtime_env import (
#       4     get_docker_compose_command,
#       5     get_docker_compose_version,
#       6     get_docker_environment,
#       7     get_docker_version,
#       8     get_langchain_env_var_metadata,
#       9     get_langchain_env_vars,
#      10     get_langchain_environment,
#      11     get_release_shas,
#      12     get_runtime_and_metrics,
#      13     get_runtime_environment,
#      14     get_system_metrics,
#      15 )
#      17 __all__ = [
#      18     "get_docker_compose_command",
#      19     "get_docker_compose_version",
#    (...)     29     "get_git_info",
#      30 ]
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\env\_runtime_env.py:10
#       7 import subprocess
#       8 from typing import Dict, List, Optional, Union
# ---> 10 from langsmith.utils import get_docker_compose_command
#      11 from langsmith.env._git import exec_git
#      13 try:
#      14     # psutil is an optional dependency
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\utils.py:31
#      28 import requests
#      29 from urllib3.util import Retry
# ---> 31 from langsmith import schemas as ls_schemas
#      33 _LOGGER = logging.getLogger(__name__)
#      36 class LangSmithError(Exception):
#
# File c:\invest_project\AI\venv\Lib\site-packages\langsmith\schemas.py:69
#      65     created_at: datetime = Field(default_factory=lambda: datetime.now(timezone.utc))
#      66     split: Optional[Union[str, List[str]]] = None
# ---> 69 class Example(ExampleBase):
#      70     """Example model."""
#      72     id: UUID
#
# File c:\invest_project\AI\venv\Lib\site-packages\pydantic\v1\main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File c:\invest_project\AI\venv\Lib\site-packages\pydantic\v1\main.py:807, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     801 @classmethod
#     802 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     803     """
#     804     Same as update_forward_refs but will not raise exception
#     805     when forward references are not defined.
#     806     """
# --> 807     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File c:\invest_project\AI\venv\Lib\site-packages\pydantic\v1\typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File c:\invest_project\AI\venv\Lib\site-packages\pydantic\v1\typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File c:\invest_project\AI\venv\Lib\site-packages\pydantic\v1\typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'
